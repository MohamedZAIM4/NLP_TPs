# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedZAIM4/Pre-processing/blob/main/Tp1%C2%A0_Text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import re
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7a391ed-5d2e-425c-b145-6ee2c0c114f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7a391ed-5d2e-425c-b145-6ee2c0c114f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Check the uploaded file names
file_names = list(uploaded.keys())
print("Uploaded file names:", file_names)

# Use the correct filename based on what you see in the output
filename = 'sample (4).csv'

# Load the data
data = pd.read_csv(io.BytesIO(uploaded[filename]))

# Display the data
data.head()
# Out:
# Uploaded file names: ['sample (4).csv']
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @AppleSupport causing the reply to be disregar...            119236
# 1  @105835 Your business means a lot to us. Pleas...               NaN
# 2  @76328 I really hope you all change but I'm su...            119238
# 3  @105836 LiveChat is online at the moment - htt...            119241
# 4  @VirginTrains see attached error message. I've...            119243
#
#    in_response_to_tweet_id
# 0                      NaN
# 1                 119239.0
# ...

# %%
def clean_text(text):

    text = text.lower()

    text = re.sub(r'[^\w\s]', '', text)

    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

data['text_cleaned'] = data['text'].apply(clean_text)

# %%
word_freq = {}
for text in data['text_cleaned']:
    words = text.split()
    for word in words:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1


threshold = 2
rare_words = [word for word, freq in word_freq.items() if freq <= threshold]


data['text_cleaned'] = data['text_cleaned'].apply(lambda x: ' '.join([word for word in x.split() if word not in rare_words]))
data.head(15)
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# 5     119243  VirginTrains    False  Tue Oct 10 15:25:14 +0000 2017
# 6     119244        105836     True  Tue Oct 10 15:26:44 +0000 2017
# 7     119245  VirginTrains    False  Tue Oct 10 15:33:22 +0000 2017
# 8     119242        105836     True  Tue Oct 10 15:09:00 +0000 2017
# 9     119246  VirginTrains    False  Tue Oct 10 10:13:19 +0000 2017
# 10    119248  AppleSupport    False  Wed Oct 11 13:38:29 +0000 2017
# 11    119249        105837     True  Wed Oct 11 07:37:27 +0000 2017
# 12    119250        105838     True  Wed Oct 11 05:33:17 +0000 2017
# ...

# %%
stemmer = PorterStemmer()

data['text_stemmed'] = data['text_cleaned'].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
from bs4 import BeautifulSoup
def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"
                               u"\U0001F300-\U0001F5FF"
                               u"\U0001F680-\U0001F6FF"
                               u"\U0001F1E0-\U0001F1FF"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)


def remove_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

data['text_cleaned'] = data['text_cleaned'].apply(remove_emojis)


data['text_cleaned'] = data['text_cleaned'].apply(remove_urls)

data['text_cleaned'] = data['text_cleaned'].apply(remove_html_tags)

data_cleaned = data[['tweet_id', 'text', 'text_cleaned']]

data_cleaned.head(15)
# Out:
#     tweet_id                                               text  \
# 0     119237  @AppleSupport causing the reply to be disregar...
# 1     119238  @105835 Your business means a lot to us. Pleas...
# 2     119239  @76328 I really hope you all change but I'm su...
# 3     119240  @105836 LiveChat is online at the moment - htt...
# 4     119241  @VirginTrains see attached error message. I've...
# 5     119243  @105836 Have you tried from another device, Mi...
# 6     119244  @VirginTrains yep, I've tried laptop too sever...
# 7     119245  @105836 It's working OK from here, Miriam. Doe...
# 8     119242  @VirginTrains I still haven't heard &amp; the ...
# 9     119246  @105836 That's what we're here for Miriam 😊  T...
# 10    119248  @105837 We can help. Which version of iOS are ...
# 11    119249  @105838 @AppleSupport Me too am suffering , ho...
# 12    119250  @AppleSupport hi #apple, I’ve a concern about ...
# 13    119252  @105839 Thanks for reaching out to us. We are ...
# ...
